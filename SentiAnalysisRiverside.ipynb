# %% [markdown]
# ## Sentiment Analysis of Patient Reviews
# ### Overview
# Experiment using jupyter notebook to run some sentiment analysis. Crawl review data from NSH website manually.

# %%
#Download required ntlk packages and lib
import nltk
import matplotlib
nltk.download("vader_lexicon")
nltk.download("stopwords")

# %%
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
from collections import Counter
import re
import math
import html
import sklearn
import sklearn.metrics as metrics
from sklearn.metrics import mutual_info_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint

# %matplotlib inline

# %%
# Testing
#Sentences to try with vader
sentences = ["VADER is smart, handsome, and funny.",
             "Data Scientists are sexy!",
             "The room was dirty and small",
             "They had excellent facilities!",
             "This hotel is the worst hotel in the city"]
sid = SentimentIntensityAnalyzer()
for sentence in sentences:
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
         print('{0}: {1}, '.format(k, ss[k]), end='')
    print('\n')
# Out:
# VADER is smart, handsome, and funny.
# compound: 0.8316, neg: 0.0, neu: 0.254, pos: 0.746,
#
# Data Scientists are sexy!
# compound: 0.5707, neg: 0.0, neu: 0.448, pos: 0.552,
#
# The room was dirty and small
# compound: -0.4404, neg: 0.367, neu: 0.633, pos: 0.0,
#
# They had excellent facilities!
# compound: 0.6114, neg: 0.0, neu: 0.429, pos: 0.571,
#
# This hotel is the worst hotel in the city
# compound: -0.6249, neg: 0.339, neu: 0.661, pos: 0.0,

# %%
revframe = pd.read_csv('Riverside.txt', sep='\t', lineterminator='\n')
revframe.columns = ['Date','Stars','Title','Review']
revframe.head()
# Out:
#                Date  Stars                                              Title  \
# 0       03-May-2019      2  Surely you should be listened too and made to ...
# 1  27-February-2019      1                         Appalling customer service
# 2   20-January-2019      1                          unable to get appointment
# 3      26-July-2018      3                          Impossible to get through
# 4      12-June-2018      2  Not able to get appoitment due to extremly rud...
#
#                                               Review
# 0  Both my wife and I are patients presently regi...
# 1  I'd love to be emailing the bellow to the prac...
# 2  Have attended on several occasions and have ne...
# 3  Don't try and ring them - there's usually one ...
# 4  We are new to the town and wanted to register ...

# %%
sid = SentimentIntensityAnalyzer()
vaderScores = []
for rn, review in enumerate(revframe['Review']):
    scores = sid.polarity_scores(review)
    vaderScores.append(scores['compound'])
revframe = revframe.assign(vaderScore = vaderScores)
revframe.head()
# Out:
#                Date  Stars                                              Title  \
# 0       03-May-2019      2  Surely you should be listened too and made to ...
# 1  27-February-2019      1                         Appalling customer service
# 2   20-January-2019      1                          unable to get appointment
# 3      26-July-2018      3                          Impossible to get through
# 4      12-June-2018      2  Not able to get appoitment due to extremly rud...
#
#                                               Review  vaderScore
# 0  Both my wife and I are patients presently regi...      0.9060
# 1  I'd love to be emailing the bellow to the prac...      0.6485
# 2  Have attended on several occasions and have ne...     -0.9398
# 3  Don't try and ring them - there's usually one ...      0.4753
# 4  We are new to the town and wanted to register ...      0.5837

# %%
ratingByStars = revframe.sort_values('Stars', ascending=False)
ratingByStars.head(10)
# Out:
#                 Date  Stars  \
# 9    24-January-2018      5
# 7    02-January-2018      5
# 16      10-July-2017      5
# 13   09-October-2017      5
# 11  05-December-2017      5
# 8    19-January-2018      5
# 17      27-June-2017      5
# 6       26-July-2018      5
# 3       26-July-2018      3
# 5       06-July-2018      2
#
#                                                 Title  \
# 9      Excellent Customer Service - Medical Secretary
# 7                                         A good team
# 16                               Thank you Riverside
# 13                                         Blood test
# 11                                Thank you Riverside
# 8                         Riverside practice feedback
# 17                                  Well looked after
# 6   they always sort me out and i cannot praise th...
# 3                           Impossible to get through
# 5              Reception staff rarely nice or helpful
#
#                                                Review  vaderScore
# 9   I phoned the medical secretary at Riverside Pr...      0.9897
# 7   My wife and I have been with Riverside for som...      0.6359
# 16  I needed to use the services at Riverside last...      0.9740
# 13  I had an appointment this morning to have a bl...     -0.9012
# 11  I am new to the Practice and felt that the way...      0.8687
# 8   I am truly happy with the service provided at ...      0.9875
# 17  I visited the doctor today who was kind when I...      0.4911
# 6   I have enjoyed an excellent relationship with ...      0.3818
# 3   Don't try and ring them - there's usually one ...      0.4753
# 5   Have been at the surgery for years and always ...     -0.4354

# %%
ratingByVader = revframe.sort_values('vaderScore', ascending=False)
ratingByVader.head(10)
# Out:
#                 Date  Stars  \
# 9    24-January-2018      5
# 8    19-January-2018      5
# 16      10-July-2017      5
# 15   07-October-2017      1
# 0        03-May-2019      2
# 11  05-December-2017      5
# 12  29-December-2017      1
# 1   27-February-2019      1
# 7    02-January-2018      5
# 4       12-June-2018      2
#
#                                                 Title  \
# 9      Excellent Customer Service - Medical Secretary
# 8                         Riverside practice feedback
# 16                               Thank you Riverside
# 15  my experience with this practice is .............
# 0   Surely you should be listened too and made to ...
# 11                                Thank you Riverside
# 12                                   Quite a let down
# 1                          Appalling customer service
# 7                                         A good team
# 4   Not able to get appoitment due to extremly rud...
#
#                                                Review  vaderScore
# 9   I phoned the medical secretary at Riverside Pr...      0.9897
# 8   I am truly happy with the service provided at ...      0.9875
# 16  I needed to use the services at Riverside last...      0.9740
# 15  I find the practice as a whole the shambles. y...      0.9490
# 0   Both my wife and I are patients presently regi...      0.9060
# 11  I am new to the Practice and felt that the way...      0.8687
# 12  My Wife had to attend this practice only yeste...      0.8501
# 1   I'd love to be emailing the bellow to the prac...      0.6485
# 7   My wife and I have been with Riverside for som...      0.6359
# 4   We are new to the town and wanted to register ...      0.5837

# %%
def get_topk_ngram(df, ngram_range=(1,1), k=None, stopwords=True, with_count=False):
    '''
    Extract the most frequently occurred words in countvector
    '''
    vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words='english', max_features=k)
    countvector = vectorizer.fit_transform(df['Review'])

    # Get topk occurred ngrams
    topk_words = []
    sortedindices = countvector.toarray().sum(axis=0).argsort()[::-1][:k]
    counts = countvector.toarray().sum(axis=0)
    
    for i in sortedindices:
        word = vectorizer.get_feature_names()[i]
        
        if with_count:
            count = counts[i]
            topk_words.append((word, count))
        else:
            topk_words.append(word)
            
    return topk_words

topkPos = get_topk_ngram(revframe.loc[revframe['Stars']>=3], ngram_range=(1,1), k=10, with_count=True)
print("The most frequently occured top 10 words in positive reviews")
pprint(pd.DataFrame(topkPos, columns=['Word', 'Count']))

topkNeg = get_topk_ngram(revframe.loc[revframe['Stars']<3], ngram_range=(1,1), k=10, with_count=True)
print("The most frequently occured top 10 words in negative reviews")
pprint(pd.DataFrame(topkNeg, columns=['Word', 'Count']))

topkPos_bigram = get_topk_ngram(revframe.loc[revframe['Stars']>=3], ngram_range=(2,2), k=10, with_count=True)
print("The most frequently occured top 10 bigrams in positive reviews")
pprint(pd.DataFrame(topkPos_bigram, columns=['Bigram', 'Count']))

topkNeg_bigram = get_topk_ngram(revframe.loc[revframe['Stars']<3], ngram_range=(2,2), k=10, with_count=True)
print("The most frequently occured top 10 bigrams in negative reviews")
pprint(pd.DataFrame(topkNeg_bigram, columns=['Bigram', 'Count']))
# Out:
# The most frequently occured top 10 words in positive reviews
#           Word  Count
# 0  appointment      7
# 1      surgery      6
# 2      helpful      6
# 3      service      5
# 4         good      5
# 5       doctor      5
# 6    riverside      4
# 7         know      4
# 8          ill      4
# 9        blood      4
# The most frequently occured top 10 words in negative reviews
#            Word  Count
# 0   appointment     13
# 1      practice     10
# 2        doctor      8
# 3          wife      7
# 4  receptionist      6
# 5       surgery      5
# 6         staff      5
# 7        trying      4
# 8     riverside      4
# 9     reception      4
# The most frequently occured top 10 bigrams in positive reviews
#                   Bigram  Count
# 0        reception staff      3
# 1     separate occasions      2
# 2      referred hospital      2
# 3      medical secretary      2
# 4     secretary attended      1
# 5             saw doctor      1
# 6      receptionist sure      1
# 7  receptionist advanced      1
# 8          received good      1
# 9       reassuring refer      1
# The most frequently occured top 10 bigrams in negative reviews
#                    Bigram  Count
# 0            quarter past      2
# 1           point contact      2
# 2      online appointment      2
# 3               make feel      2
# 4     appointment doctors      2
# 5     properly instructed      1
# 6      professions needed      1
# 7  professionalism caring      1
# 8          problems point      1
# 9          problem mother      1

# %%
def getPMI_ngram(df, gt, ngram_range=(1,1), max_features=50):
    vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words='english', max_features=max_features)
    countvector = vectorizer.fit_transform(df['Review'])
    densevector = np.array(countvector.todense())
    
    px = sum(df['Stars'] >= 3) / len(df)
    if gt == 'negative':
        px = sum(df['Stars'] < 3) / len(df)
        
    pmis = []
    
    for i in range(max_features):
        py = sum(densevector[:,i] == 1) / len(df)
        pxy = len(df[(df['Stars'] >= 3) & (densevector[:,i] == 1)]) / len(df)
        if gt == 'negative':
            pxy = len(df[(df['Stars'] < 3) & (densevector[:,i] == 1)]) / len(df)
        
        if pxy == 0:
            pmi = math.log10((pxy + 0.0001) / (px * py))
        else:
            pmi = math.log10(pxy / (px * py))
            
        pmis.append(pmi)
        
    pmis = pd.DataFrame(data = {'pmi' + gt: pmis}, index = vectorizer.get_feature_names())
    return pmis.sort_values('pmi' + gt, ascending=False)

# %%
# pmiPos_unigram = getPMI_ngram(revframe, 'positive')
# print('PMI for positive reviews - Unigram')
# pmiPos_unigram.head()

# pmiNeg_unigram = getPMI_ngram(revframe, 'negative')
# print('PMI for negative reviews - Unigram')
# pmiNeg_unigram.head()

# pmiPos_bigram = getPMI_ngram(revframe, 'positive', ngram_range=(2,2))
# print('PMI for positive reviews - Bigram')
# pmiPos_bigram.head()

# pmiNeg_bigram = getPMI_ngram(revframe, 'negative', ngram_range=(2,2))
# print('PMI for negative reviews - Bigram')
# pmiNeg_bigram.head()

# %%
y = revframe['Stars'].values
x = revframe['vaderScore'].values
plt.title('Vader score vs. True Ratings')
plt.xlabel('Vader Scores')
plt.ylabel('True Ratings')
plt.xticks([-1, -0.5, 0, 0.5, 1])
plt.yticks([1,2,3,4,5])
plt.plot(x, y, "o", ms=3, color='b')
plt.show()

# %%
#Overlayed Histogram for GT rating and VD score
#Just for demonstrating, I am dividing the rating score by 5
x = [revframe['Stars'].values / 5]
y = [(revframe['vaderScore'].values + 1 )/ 2]
bins = np.linspace(0, 1, 100)
plt.hist(x, bins, label='Rescaled True Ratings')
plt.hist(y, bins, label='Rescaled Vader Scores')
plt.title('Histogram - Rescaled')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend(loc='upper left')
plt.show()

# %%
plt.xlabel('Rating Score')
revframe['Stars'].plot(kind='hist', title='Histogram - Rating Scores', bins=np.arange(1,7)-0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-69-08c9030fe831> in <module>
#       1 plt.xlabel('Rating Score')
# ----> 2 revframe['Stars'].plot(kind='hist', title='Histogram - Rating Scores', bins=np.arange(1,7)-0.5)
#       3 plt.show()
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1797                     data.columns = label_name
#    1798
# -> 1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
#    1801     plot_obj.generate()
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, bins, bottom, **kwargs)
#    1314         self.bottom = bottom
#    1315         # Do not call LinePlot.__init__ which may fill nan
# -> 1316         MPLPlot.__init__(self, data, **kwargs)
#    1317
#    1318     def _args_adjust(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#      96                  table=False, layout=None, **kwds):
#      97
# ---> 98         _raise_if_no_mpl()
#      99         _converter._WARN = False
#     100         self.data = data
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in _raise_if_no_mpl()
#      46     # TODO(mpl_converter): remove once converter is explicit
#      47     if not _HAS_MPL:
# ---> 48         raise ImportError("matplotlib is required for plotting.")
#      49
#      50
#
# ImportError: matplotlib is required for plotting.
